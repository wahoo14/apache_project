# %%
import pandas as pd

# %%
ranges = pd.read_csv(r"C:\Users\David\Desktop\Python\Apache\data\ranges.csv")
print(ranges.head())
# Out:
# Empty DataFrame
# ...

# %%
intensities = pd.read_csv(r"C:\Users\David\Desktop\Python\Apache\data\intensities.csv")
print(intensities.head())
# Out:
# Empty DataFrame
# ...
